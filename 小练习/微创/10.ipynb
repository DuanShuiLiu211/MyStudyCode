# %%
import cv2
import numpy as np
from PIL import Image
import SimpleITK as sitk
import matplotlib.pyplot as plot

# %%
label_file_name = "/Volumes/昊大侠/工作/实习相关/微创卜算子医疗科技有限公司/陈嘉懿组/数据/短轴动态狭窄率/result/狭窄率图表_0920/测试集去除分叉帧数据及结果/label/02220820210305_XJ_20210305082931543.nii.gz"

label = sitk.GetArrayFromImage(sitk.ReadImage(label_file_name))

# %%
label.shape
# Out:
# (72, 203, 195)

# %%
Image.fromarray(label[0] * 127)  # outside -> inside 0 -> 76/1 -> 149/2
# Out:
# <PIL.Image.Image image mode=L size=195x203>

# %%
image_file_name = "/Volumes/昊大侠/工作/实习相关/微创卜算子医疗科技有限公司/陈嘉懿组/数据/短轴动态狭窄率/result/狭窄率图表_0920/测试集去除分叉帧数据及结果/rvm/02220820210305_XJ_20210305082931543.nii.gz"

image = sitk.GetArrayFromImage(sitk.ReadImage(image_file_name))

# %%
image.shape
# Out:
# (72, 128, 128)

# %%
plot.imshow(image[0])

# %% [markdown]
# 1. 02220820210305_XJ_20210305082931543.nii.gz -> 去除0-5共6帧
# 2. 202204020917510011VAS.nii.gz -> 去除0-28共29帧
# 3. IM_0044.nii.gz -> 去除73-136共64帧

# %%
image_1 = cv2.imread(
    "/Volumes/昊大侠/工作/实习相关/微创卜算子医疗科技有限公司/陈嘉懿组/数据/短轴动态狭窄率/result/狭窄率图表_0920/测试集去除分叉帧数据及结果/狭窄帧_人工选图_人工标注/image/02220820210305_XJ_20210305082931543_60.png"
)

image_2 = cv2.imread(
    "/Volumes/昊大侠/工作/实习相关/微创卜算子医疗科技有限公司/陈嘉懿组/数据/短轴动态狭窄率/result/狭窄率图表_0920/测试集去除分叉帧数据及结果/狭窄帧_人工选图_人工标注/image/0121.png"
)

label_1 = cv2.imread(
    "/Volumes/昊大侠/工作/实习相关/微创卜算子医疗科技有限公司/陈嘉懿组/数据/短轴动态狭窄率/result/狭窄率图表_0920/测试集去除分叉帧数据及结果/狭窄帧_人工选图_人工标注/label/02220820210305_XJ_20210305082931543_60.png"
)

# %%
Image.fromarray(cv2.addWeighted(image_1, 0.8, label_1, 0.2, 0))
# Out:
# <PIL.Image.Image image mode=RGB size=896x672>

# %%
# a = sitk.ReadImage(
#     "/Volumes/昊大侠/工作/实习相关/微创卜算子医疗科技有限公司/陈嘉懿组/数据/短轴动态狭窄率/dataset/1018/label/_20210128075939_0818060/0069.png"
# )
a = cv2.imdecode(
    np.fromfile(
        "/Volumes/昊大侠/工作/实习相关/微创卜算子医疗科技有限公司/陈嘉懿组/数据/短轴动态狭窄率/dataset/1018/label/_20210128075939_0818060/0069.png",
        dtype=np.uint8,
    ),
    -1,
)
# b = sitk.GetArrayFromImage(a)

print(a.shape[0], a.shape[1])
# Out:
# 672 896
