# %%
import cv2
import numpy as np
from PIL import Image
import SimpleITK as sitk

# %%
label = sitk.GetArrayFromImage(sitk.ReadImage("/Users/WangHao/Desktop/label_smooth_by_polarozation/_20210128075939_0818060.nii.gz"))

# %%
Image.fromarray(label[0])  # outside -> inside 0 -> 76 -> 149
# Out:
# <PIL.Image.Image image mode=L size=896x672 at 0x169F1E0A0>

# %%
image = sitk.GetArrayFromImage(sitk.ReadImage("/Users/WangHao/Desktop/_20210128075939_0818060.nii.gz"))

# %%
Image.fromarray(image[0])
# Out:
# <PIL.Image.Image image mode=L size=309x255 at 0x124270D60>
