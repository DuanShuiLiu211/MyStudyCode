# %%
import cv2
import numpy as np
from PIL import Image
import SimpleITK as sitk
import matplotlib.pyplot as plot

# %%
label = sitk.GetArrayFromImage(
    sitk.ReadImage(
        "/Volumes/昊大侠/工作/实习相关/微创卜算子医疗科技有限公司/陈嘉懿组/数据/短轴动态狭窄率/result/狭窄率图表_0920/label/_20210128075939_0818310.nii.gz"
    ))

# %%
Image.fromarray(label[0] * 127)  # outside -> inside 0 -> 76/1 -> 149/2
# Out:
# <PIL.Image.Image image mode=L size=296x268>

# %%
image = sitk.GetArrayFromImage(
    sitk.ReadImage(
        "/Volumes/昊大侠/工作/实习相关/微创卜算子医疗科技有限公司/陈嘉懿组/数据/短轴动态狭窄率/result/狭窄率图表_0920/rvm/_20210128075939_0818310.nii.gz"
    ))

# %%
plot.imshow(image[0])
